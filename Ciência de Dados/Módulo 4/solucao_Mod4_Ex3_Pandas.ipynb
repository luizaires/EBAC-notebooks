# %% [markdown]
# <img src="https://raw.githubusercontent.com/andre-marcos-perez/ebac-course-utils/main/media/logo/newebac_logo_black_half.png" alt="ebac-logo">
#
# ---
#
# # **Módulo 4 Parte III** | Leitura de arquivos
# **Exercícios**<br>
# [Luiz Aires](https://github.com/luizaires)
#
# ---

# %% [markdown]
# # Tarefa 03
#
# - Leia os enunciados com atenção
# - Saiba que pode haver mais de uma resposta correta
# - Insira novas células de código sempre que achar necessário
# - Em caso de dúvidas, procure os Tutores
# - Divirta-se :)

# %%
import pandas as pd
import requests

# %% [markdown]
# ####  1) Lendo de APIs
# Vimos em aula como carregar dados públicos do governo através de um API (*Application Programming Interface*). No exemplo de aula, baixamos os dados de pedidos de verificação de limites (PVL) realizados por estados, e selecionamos apenas aqueles referentes ao estado de São Paulo.
#
# 1. Repita os mesmos passos feitos em aula, mas selecione os PVLs realizados por municípios no estado do Rio de Janeiro.
# 2. Quais são os três *status* das solicitações mais frequentes na base? Quais são suas frequências?
# 3. Construa uma nova variável que contenha o ano do **status**. Observe que ```data_status``` vem como tipo *object* no **DataFrame**. Dica: você pode usar o método ```.str``` para transformar o tipo da variável em string, em seguida um método como [**slice()**](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.slice.html) ou [**split()**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.split.html).
# 4. Indique a frequência de cada ano do campo construído no item (3).

# %%
# Parte 1
url = 'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf=RJ&tipo_interessado=Estado'
r = requests.get(url)
data_json = r.json()
df = pd.DataFrame(data_json['items'])

# %%
df.head()
# Out:
#    id_pleito tipo_interessado     interessado  cod_ibge  uf num_pvl  \
# 0       7150           Estado  Rio de Janeiro        33  RJ    None
# 1       9898           Estado  Rio de Janeiro        33  RJ    None
# 2       5943           Estado  Rio de Janeiro        33  RJ    None
# 3      13634           Estado  Rio de Janeiro        33  RJ    None
# 4       7525           Estado  Rio de Janeiro        33  RJ    None
#
#                                               status          num_processo  \
# 0  Encaminhado à PGFN com manifestação técnica fa...  17944.000508/2012-01
# 1                                           Deferido  17944.001076/2010-85
# 2  Encaminhado à PGFN com manifestação técnica fa...  17944.000240/2012-07
# 3                                           Deferido  19405.000041/2002-41
# 4                                           Deferido  17944.000599/2009-71
#
#          data_protocolo                                      tipo_operacao  \
# ...

# %% [markdown]
# ---

# %%
#Parte 2
df['status'].value_counts()
# Out:
# Encaminhado à PGFN com manifestação técnica favorável    34
# Deferido                                                 14
# Arquivado a pedido                                        3
# Arquivado por decurso de prazo                            1
# Name: status, dtype: int64

# %% [markdown]
# ---

# %%
#Parte 3
df['ano_status'] = df['data_status'].str[6:]
df.head()
# Out:
#    id_pleito tipo_interessado     interessado  cod_ibge  uf num_pvl  \
# 0       7150           Estado  Rio de Janeiro        33  RJ    None
# 1       9898           Estado  Rio de Janeiro        33  RJ    None
# 2       5943           Estado  Rio de Janeiro        33  RJ    None
# 3      13634           Estado  Rio de Janeiro        33  RJ    None
# 4       7525           Estado  Rio de Janeiro        33  RJ    None
#
#                                               status          num_processo  \
# 0  Encaminhado à PGFN com manifestação técnica fa...  17944.000508/2012-01
# 1                                           Deferido  17944.001076/2010-85
# 2  Encaminhado à PGFN com manifestação técnica fa...  17944.000240/2012-07
# 3                                           Deferido  19405.000041/2002-41
# 4                                           Deferido  17944.000599/2009-71
#
#          data_protocolo                                      tipo_operacao  \
# ...

# %% [markdown]
# ---

# %%
#Parte 4
df.ano_status.value_counts()
# Out:
# 2012    11
# 2009     9
# 2013     7
# 2011     6
# 2014     4
# 2016     4
# 2002     4
# 2010     3
# 2006     2
# 2008     2
# Name: ano_status, dtype: int64

# %% [markdown]
# ---

# %% [markdown]
# ####  2) Melhorando a interação com o API
# Observe dois URLs de consultas diferentes, por exemplo o URL utilizado em aula, e o URL feito no exercício anterior. Compare-os e observe as diferenças.
#
# 1. Faça uma função em Python que recebe como argumento o UF da consulta e o tipo de interessado (```'Estado'```ou ```Município```), e que devolve os dados da consulta no formato *DataFrame*.
# 2. Quantas solicitações para o Estado podem ser consultadas para Minas Gerais com *status* em 'Arquivado por decurso de prazo' estão registradas?
# 3. Qual é o município da Bahia com mais solicitações deferidas?
# 4. Salve um arquivo .csv com os dados de solicitações da Bahia, com interessado = 'Estado'

# %%
#Parte 1

def pvl_api_consulta(uf: str, tipo_de_interessado: str):
    lista_uf = ['AC','AL','AP','AM','BA','CE','DF','ES','GO','MA','MT','MS','MG','PA',
                'PB','PR','PE','PI','RJ','RN','RS','RO','RR','SC','SP','SE','TO']
    interesados = ['Estado','Município']
    df_consulta = -99999
    if uf in lista_uf:
        if tipo_de_interessado in interesados:
            print('A consuta retornou um resultado')
            url = f'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf={uf}&tipo_interessado={tipo_de_interessado}'
            r  = requests.get(url)
            dados = r.json()
            df_consulta = pd.DataFrame(dados['items'])
        else:
            print("O tipo de interessado inválido! Por favor, informe um dos seguintes valores: 'Estado','Município'")
    else:
        print("UF inválido! Por favor, informe uma sigla para unidade federativa válida")
    return df_consulta

# %% [markdown]
# ---

# %%
#Parte 2
df_mg = pvl_api_consulta('MG', 'Estado')
df_mg.head(2)
# Out:
# A consuta retornou um resultado
#    id_pleito tipo_interessado   interessado  cod_ibge  uf num_pvl  \
# 0       5582           Estado  Minas Gerais        31  MG    None
# 1       6917           Estado  Minas Gerais        31  MG    None
#
#                                               status          num_processo  \
# 0                                 Arquivado a pedido  17944.000148/2013-10
# 1  Encaminhado à PGFN com manifestação técnica fa...  17944.000458/2012-53
#
#          data_protocolo                                      tipo_operacao  \
# 0  2013-04-02T03:00:00Z  Operação contratual externa (com garantia da U...
# 1  2012-07-05T03:00:00Z  Operação contratual externa (com garantia da U...
#
#                                           finalidade  \
# 0                                     Infraestrutura
# 1  Reestruturação e recomposição do principal de ...
#
#                             tipo_credor                        credor  \
# ...

# %%
sum(df_mg['status'] == 'Arquivado por decurso de prazo')
# Out:
# 1

# %% [markdown]
# ---

# %%
#Parte 3
df_ba = pvl_api_consulta('BA', 'Município')
df_ba.head(2)
# Out:
# A consuta retornou um resultado
#    id_pleito tipo_interessado interessado  cod_ibge  uf num_pvl    status  \
# 0       8349        Município  Terra Nova   2931707  BA    None  Deferido
# 1       8356        Município  Terra Nova   2931707  BA    None  Deferido
#
#            num_processo        data_protocolo                tipo_operacao  \
# 0  17944.000761/2009-51  2009-08-25T03:00:00Z  Operação contratual interna
# 1  17944.000762/2009-03  2009-08-25T03:00:00Z  Operação contratual interna
#
#                                        finalidade  \
# 0  Aquisição de máquinas, equipamentos e veículos
# 1  Aquisição de máquinas, equipamentos e veículos
#
#                        tipo_credor                                     credor  \
# 0  Instituição Financeira Nacional  Agência de Fomento do Estado da Bahia S/A
# 1  Instituição Financeira Nacional  Agência de Fomento do Estado da Bahia S/A
#
#   moeda     valor  pvl_assoc_divida  pvl_contradado_credor data_status
# ...

# %%
df_ba.loc[df_ba['status'] == 'Deferido', 'interessado'].value_counts()
# Out:
# Luís Eduardo Magalhães    14
# Vitória da Conquista      11
# Lauro de Freitas          10
# Camaçari                  10
# Barreiras                  8
#                           ..
# Mansidão                   1
# Ibotirama                  1
# Malhada                    1
# Licínio de Almeida         1
# Esplanada                  1
# Name: interessado, Length: 172, dtype: int64

# %% [markdown]
# Luís Eduardo Magalhães é o município da Bahia com maior número de solicitações deferidas, 14 solicitações no total.

# %% [markdown]
# ---

# %%
# 4) Seu código aqui
df_BA = pvl_api_consulta('BA', 'Estado')
df_BA.to_csv('uf_BA_interessado_Estado.csv', index = False, sep = ',', decimal = '.')
# Out:
# A consuta retornou um resultado

# %% [markdown]
# ---
